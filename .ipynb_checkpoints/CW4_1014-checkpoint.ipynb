# %% [markdown]
# # DA Classwork 4: Data Preparation
#
# This classwork will cover:
# - Handle missing values
# - Data Standardization
# - Data normalization
# - Binning
# - Dummy encoding

# %% [markdown]
# ## Import Data

# %% [markdown]
# Download and save the "auto.csv" (i.e., the Automobile Data Set). We will be using this data set.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Import data to dataframe

# %%
filename = "auto.csv"

# %%
df = pd.read_csv(filename)

# %%
# Display the first 5 rows
df.head()
# Out:
#    id  type  symboling  normalized-losses         make fuel-type aspiration  \
# 0   1  auto          3                NaN  alfa-romero       gas        std
# 1   2  auto          3                NaN  alfa-romero       gas        std
# 2   3  auto          1                NaN  alfa-romero       gas        std
# 3   4  auto          2              164.0         audi       gas        std
# 4   5  auto          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels  ... engine-size  fuel-system  bore  \
# 0          two  convertible          rwd  ...         130         mpfi  3.47
# 1          two  convertible          rwd  ...         130         mpfi  3.47
# 2          two    hatchback          rwd  ...         152         mpfi  2.68
# 3         four        sedan          fwd  ...         109         mpfi  3.19
# 4         four        sedan          4wd  ...         136         mpfi  3.19
#
# ...

# %%
# Display the bottom 10 rows 
df.tail(10)
# Out:
#       id  type  symboling  normalized-losses   make fuel-type aspiration  \
# 195  196  auto         -1               74.0  volvo       gas        std
# 196  197  auto         -2              103.0  volvo       gas        std
# 197  198  auto         -1               74.0  volvo       gas        std
# 198  199  auto         -2              103.0  volvo       gas      turbo
# 199  200  auto         -1               74.0  volvo       gas      turbo
# 200  201  auto         -1               95.0  volvo       gas        std
# 201  202  auto         -1               95.0  volvo       gas      turbo
# 202  203  auto         -1               95.0  volvo       gas        std
# 203  204  auto         -1               95.0  volvo    diesel      turbo
# 204  205  auto         -1               95.0  volvo       gas      turbo
#
#     num-of-doors body-style drive-wheels  ... engine-size  fuel-system  bore  \
# 195         four      wagon          rwd  ...         141         mpfi  3.78
# ...

# %% [markdown]
# Find the data types of the columns

# %%
# column data types
df.dtypes
# Out:
# id                     int64
# type                  object
# symboling              int64
# normalized-losses    float64
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                 float64
# stroke               float64
# compression-ratio    float64
# horsepower           float64
# peak-rpm             float64
# city-mpg               int64
# highway-mpg            int64
# price                float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 205 non-null    int64
#  1   type               205 non-null    object
#  2   symboling          205 non-null    int64
#  3   normalized-losses  164 non-null    float64
#  4   make               205 non-null    object
#  5   fuel-type          205 non-null    object
#  6   aspiration         205 non-null    object
#  7   num-of-doors       203 non-null    object
#  8   body-style         205 non-null    object
#  9   drive-wheels       205 non-null    object
#  10  engine-location    205 non-null    object
#  11  wheel-base         205 non-null    float64
#  12  length             205 non-null    float64
#  13  width              205 non-null    float64
#  14  height             205 non-null    float64
#  15  curb-weight        205 non-null    int64
# ...

# %%
# size of data
df.shape
# Out:
# (205, 28)

# %% [markdown]
# Get summary statistics of all numeric columns

# %%
# describe all numeric columns
df.describe()
# Out:
#                id   symboling  normalized-losses  wheel-base      length  \
# count  205.000000  205.000000         164.000000  205.000000  205.000000
# mean   103.000000    0.834146         122.000000   98.756585  174.049268
# std     59.322565    1.245307          35.442168    6.021776   12.337289
# min      1.000000   -2.000000          65.000000   86.600000  141.100000
# 25%     52.000000    0.000000          94.000000   94.500000  166.300000
# 50%    103.000000    1.000000         115.000000   97.000000  173.200000
# 75%    154.000000    2.000000         150.000000  102.400000  183.100000
# max    205.000000    3.000000         256.000000  120.900000  208.100000
#
#             width      height  curb-weight  engine-size        bore  \
# count  205.000000  205.000000   205.000000   205.000000  201.000000
# mean    65.907805   53.724878  2555.565854   126.907317    3.329751
# std      2.145204    2.443522   520.680204    41.642693    0.273539
# ...

# %% [markdown]
# ## Drop columns in Pandas

# %% [markdown]
# By looking at the date, we sse that the first column <code>id</code> is not meaningful for the analysis. Also, the second column <code>type</code> only contains one unique value "auto".
#
# We will drop these two columns.

# %%
df['type'].value_counts()
# Out:
# type
# auto    205
# Name: count, dtype: int64

# %%
# drop these columns

drop_list = ['id', 'type']

df = df.drop(drop_list, axis=1)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## Identify missing values

# %% [markdown]
# We the following functions to identify these missing values. There are two methods to detect missing data:
#
# 1. isnull()
# 2. notnull()
#
# The output is a boolean value indicating whether the value that is passed into the argument is in fact missing data. "True" stands for missing value, while "False" stands for not missing value.

# %%
# find missing values

#missing_data will be a dataframe, 205*28
missing_data  = df.isnull()

missing_data.head(5)
# Out:
#    symboling  normalized-losses   make  fuel-type  aspiration  num-of-doors  \
# 0      False               True  False      False       False         False
# 1      False               True  False      False       False         False
# 2      False               True  False      False       False         False
# 3      False              False  False      False       False         False
# 4      False              False  False      False       False         False
#
#    body-style  drive-wheels  engine-location  wheel-base  ...  engine-size  \
# 0       False         False            False       False  ...        False
# 1       False         False            False       False  ...        False
# 2       False         False            False       False  ...        False
# 3       False         False            False       False  ...        False
# 4       False         False            False       False  ...        False
#
# ...

# %% [markdown]
# <h4>Count missing values in each column</h4>
#
# For all the remaining columns, let’s find out the number of missing values and determine how to handle them

# %%
# use isnull() to return a DataFrame containing Boolean values, then use sum() to count null values

missing_count = missing_data.sum()

# %%
missing_count
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# Based on the summary above, seven columns containing missing data:
#
# <ol>
#     <li>"normalized-losses": 41 missing data</li>
#     <li>"num-of-doors": 2 missing data</li>
#     <li>"bore": 4 missing data</li>
#     <li>"stroke" : 4 missing data</li>
#     <li>"horsepower": 2 missing data</li>
#     <li>"peak-rpm": 2 missing data</li>
#     <li>"price": 4 missing data</li>
# </ol>

# %% [markdown]
# ## Deal with missing data
#
# **How to deal with missing data?**
#
#
# 1. drop data
#     - drop the whole row
#     - drop the whole column
# 2. replace data
#     - replace it by mean
#     - replace it by frequenct values
#     - replace it based on other functions

# %% [markdown]
# Whole columns should be dropped only if most entries in the column are missing. In our dataset, none of the columns are sparse enough to drop entirely. We have some freedom in choosing which method to replace data; however, some methods may seem more reasonable than others. We will apply each method to many different columns:
#
# <b>Replace by mean:</b>
#
# <ul>
#     <li>"normalized-losses": 41 missing data, replace them with mean</li>
#     <li>"stroke": 4 missing data, replace them with mean</li>
#     <li>"bore": 4 missing data, replace them with mean</li>
#     <li>"horsepower": 2 missing data, replace them with mean</li>
#     <li>"peak-rpm": 2 missing data, replace them with mean</li>
# </ul>
#
# <b>Replace by frequency:</b>
#
# <ul>
#     <li>"num-of-doors": 2 missing data, replace them with "four".
#         <ul>
#             <li>Reason: 84% sedans is four doors. Since four doors is most frequent, it is most likely to occur</li>
#         </ul>
#     </li>
# </ul>
#
# <b>Drop the whole row:</b>
#
# <ul>
#     <li>"price": 4 missing data, simply delete the whole row
#         <ul>
#             <li>Reason: price is what we want to predict. Any data entry without price data cannot be used for prediction; therefore any row now without price data is not useful to us</li>
#         </ul>
#     </li>
# </ul>

# %% [markdown]
# ### Replace by Mean

# %% [markdown]
# Calculate the average of the 'normalized-losses' column

# %%
# Calculate the average of the 'normalized-losses' column
avg_loss = df['normalized-losses'].mean()
df['normalized-losses'].fillna(avg_loss, inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %% [markdown]
# ## <font color='blue'> Question 1</font>
#
# <font color='blue'>**Replace missing values with mean for columns: "bore", "stroke", "horsepower", "peak-rpm"**
# </font>

# %%
# Replace missing values for 'bore' column

# %%
# Replace missing values for "stroke" column

# %%
# Replace missing values for 'horsepower' column

# %%
# Replace missing values for 'peak-rpm' column

# %% [markdown]
# Now, count missing values for these columns again

# %%
# count missing values again
null_counts = df.isnull().sum()
null_counts
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         2
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                4
# dtype: int64

# %% [markdown]
# ### Replace by Frequency

# %% [markdown]
# To see which values are present in a particular column, we can use the ".value_counts()" method:

# %%
# find unique values in a column
df['num-of-doors'].value_counts()
# Out:
# num-of-doors
# four    114
# two      89
# Name: count, dtype: int64

# %% [markdown]
# We can see that four doors are the most common type. We can also use the ".idxmax()" method to calculate for us the most common type automatically:

# %%
# find most frequent value
df['num-of-doors'].value_counts().idxmax()
# Out:
# 'four'

# %% [markdown]
# The replacement procedure is very similar to what we have seen previously

# %%
# replace the missing 'num-of-doors' values by the most frequent 
df['num-of-doors'].fillna('four', inplace=True)

# %% [markdown]
# ### Drop the Rows with missing values

# %% [markdown]
# Finally, let's drop all rows that do not have price data:

# %%
# Drop whole row with NaN in "price" column
df.dropna(subset=['price'], axis=0, inplace=True)

# %%
null_counts = df.isnull().sum()
null_counts
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 4
# stroke               4
# compression-ratio    0
# horsepower           2
# peak-rpm             2
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 201 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          201 non-null    int64
#  1   normalized-losses  201 non-null    float64
#  2   make               201 non-null    object
#  3   fuel-type          201 non-null    object
#  4   aspiration         201 non-null    object
#  5   num-of-doors       201 non-null    object
#  6   body-style         201 non-null    object
#  7   drive-wheels       201 non-null    object
#  8   engine-location    201 non-null    object
#  9   wheel-base         201 non-null    float64
#  10  length             201 non-null    float64
#  11  width              201 non-null    float64
#  12  height             201 non-null    float64
#  13  curb-weight        201 non-null    int64
#  14  engine-type        201 non-null    object
#  15  num-of-cylinders   201 non-null    object
# ...

# %% [markdown]
# Now, our datasethas no missing values.

# %% [markdown]
# ## Data Standardization
#
# Standardization is the process of transforming data into a common format which allows the researcher to make the meaningful comparison.
#
# Example: Transform **mpg** to **L/100km**
# - In our dataset, the fuel consumption columns "city-mpg" and "highway-mpg" are represented by mpg (miles per gallon) unit. Assume we are developing an application in a country that accept the fuel consumption with L/100km standard
# - We will need to transform mpg into L/100km. The formula for unit conversion is: **L/100km = 235 / mpg**

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
# Convert mpg to L/100km by mathematical operation (235 divided by mpg)
df['city-L/100km'] = 235 / df['city-mpg']

# %%
# check the transformed data 
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# ...

# %% [markdown]
# ## <font color='blue'> Question 2</font>
#
# <font color='blue'>**Also transform mpg to L/100km for the column of "highway-mpg". Name the new column as "highway-L/100km".**
# </font>

# %%
# transform mpg to L/100km by mathematical operation (235 divided by mpg)

# %% [markdown]
# ## Data Normalization
#
# Normalization is the process of transforming values of several variables into a similar range. Typical normalizations include min-max and z-score approaches.
#
# To demonstrate normalization, let's say we want to scale the column <code>length, width, height</code> using the min-max approach. This will rescale the columns to the same range [0,1]

# %% [markdown]
# Nnormalize the column <code>length</code>

# %%
# normalize the original value using min-max approach: (original-min)/(max-min)
df['length'] = (df['length'] - df['length'].min()) / (df['length'].max() - df['length'].min())

# %%
# show the scaled column
df['length'].head()
# Out:
# 0    0.413433
# 1    0.413433
# 2    0.449254
# 3    0.529851
# 4    0.529851
# Name: length, dtype: float64

# %% [markdown]
# ## <font color='blue'> Question 3</font>
#
# <font color='blue'>**Now, normalize the <code>length, width, height</code> using the min-max approach**
# </font>

# %%
# normalize width, height

# %%
# Get a summary of the data frame
normalized_list = ['length', 'width', 'height']
df[normalized_list].describe()

# %% [markdown]
# ## Binning
#
# Binning is a process of transforming continuous numerical variables into discrete categorical 'bins', for grouped analysis.
#
# Example:
#
# In our dataset, "price" is a real valued variable ranging from 5118 to 45400. We can categorize the cars into **high**, **medium**, and **low** priced cars (3 types).
#
# We will use the Pandas method 'cut' to segment the 'price' column into 3 bins

# %% [markdown]
# Lets plot the histogram of price, to see what the distribution looks like.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure()

# %%
# Visualize the distribution of car prices
sns.histplot(df["price"])
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Count'>

# %% [markdown]
# We would like 3 bins of equal size bandwidth so we use numpy's <code>linspace(start_value, end_value, numbers_generated</code> function.
#
# - We want to include the min and max values of price, so we set start_value as the min and end_value as the max of the price column.
# - Since we are building 3 bins of equal length, there should be 4 dividers, so numbers_generated=4.

# %%
# find the value dividers 
bins = np.linspace(df['price'].min(), df['price'].max(), 4)
bins
# Out:
# array([ 5118.        , 18545.33333333, 31972.66666667, 45400.        ])

# %%
# Set group names for the bins
group_names = ['Low', 'Meidum', 'High']

# %%
# We apply the function "cut" the determine what each value of car price belongs to. 
df['price-binned'] = pd.cut(df['price'], bins, labels=group_names, include_lowest=True)

# %%
df['price-binned'].head()
# Out:
# 0    Low
# 1    Low
# 2    Low
# 3    Low
# 4    Low
# Name: price-binned, dtype: category
# Categories (3, object): ['Low' < 'Meidum' < 'High']

# %% [markdown]
# Lets see the number of vehicles in each bin.

# %%
# Lets see the number of vehicles in each bin
df['price-binned'].value_counts()
# Out:
# price-binned
# Low       171
# Meidum     18
# High       12
# Name: count, dtype: int64

# %%
import warnings
# Suppress only specific types of warnings
warnings.filterwarnings('ignore', category=FutureWarning)  # Suppress future deprecation warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)  # Suppress deprecation warnings

# %%
# We can also plot the distribution of price binned values
sns.countplot(data = df, x="price-binned")
# Out:
# <Axes: xlabel='price-binned', ylabel='count'>

# %% [markdown]
# ## <font color='blue'> Question 4</font>
#
# <font color='blue'>**Now, apply binning on the <code>horsepower</code> column, make 3 bins**
# </font>

# %%
# bin the horsepower column

# %% [markdown]
# ## Indicator variable (or dummy variable)
#
# An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning.
#
# Example: We see the column "fuel-type" has two unique values, "gas" or "diesel". Regression doesn't understand words, only numbers. To use this attribute in regression analysis, we convert "fuel-type" into indicator variables.
#
# We will use the panda's method 'get_dummies' to assign numerical values to different categories of fuel type.

# %%
# get the number of unique values in a given column
df['fuel-type'].value_counts()
# Out:
# fuel-type
# gas       181
# diesel     20
# Name: count, dtype: int64

# %% [markdown]
# Get indicator variables and save them to a data frame "dummy_variable_1". For rows with <code>fuel-type</code> being 'gas', the <code>gas</code> column will be '1' and <code>diesel</code> will be '0'. Similarly for rows with <code>fuel-type</code> bing 'diesel', we will have 1 for <code>diesel</code> and 0 for <code>gas</code>.

# %%
# One-hot encoding
dummy_variable_1 = pd.get_dummies(df['fuel-type'])
dummy_variable_1.head()
# Out:
#    diesel   gas
# 0   False  True
# 1   False  True
# 2   False  True
# 3   False  True
# 4   False  True

# %% [markdown]
# Rename these two columns for clarity

# %%
# Rename these two columns 
dummy_variable_1.rename(columns = {'gas':'fuel-type-gas', 'diesel':'fuel-type-diesel'}, inplace=True )

# %%
dummy_variable_1.head()
# Out:
#    fuel-type-diesel  fuel-type-gas
# 0             False           True
# 1             False           True
# 2             False           True
# 3             False           True
# 4             False           True

# %% [markdown]
# Now, merge the dataframe <code>dummy_variable_1</code> into original dataframe <code>df</code> by concatenating the columns. The last two columns are now the dummy representations of the <code>fuel-type</code> variable. It's all 0s and 1s now.

# %%
# Merge dataframes by concatenating the columns
df = pd.concat( [df, dummy_variable_1], axis=1 )

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    compression-ratio  horsepower  peak-rpm  city-mpg highway-mpg    price  \
# ...

# %% [markdown]
# ## <font color='blue'> Question 5</font>
#
# <font color='blue'>**Create dummy variable representations for columns <code>aspiration</code> and <code>num-of-doors</code>.**
# </font>

# %%
# Create dummies for aspiration

# %%
# Create dummies for num-of-doors

# %% [markdown]
# ## <font color='blue'> Question 6</font>
#
# <font color='blue'>**Drop the columns <code>fuel-type</code>, <code>aspiration</code>, and <code>num-of-doors</code>.**
# </font>

# %%
# drop columns

# %% [markdown]
# ## Export your cleaned data
#
# save the new csv

# %%
df.to_csv('clean_df.csv')
